# %% [markdown]
# <a href="https://colab.research.google.com/github/FebryanAkt/Pembelajaran-Mesin/blob/main/T1_244107020180_Febryan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyprep

# %%
# !pip install scipy

# %%
# !pip install wandb

# %%
# !pip install scikit-learn wfdb
# !pip install --no-deps pyecg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 10.2 MB/s eta 0:00:00
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# *      PyPREP digunakan untuk preprocessing dan pembersihan noise pada data.
#
# *      SciPy digunakan untuk komputasi.
#
# *      ssfwandb digunakan untuk mencatat, melacak matriks dan memantau eksperimen secara real time.
#
#
# *      pyECG digunakan untuk membaca, memproses, dan mendeteksi pola gelombang pada data sinyal rekam jantung.

# %% [markdown]
# ---
# **Bagian 2**
#
# 1. Contoh pelanggaran etika dan hukum
# *   Plagiarisme, menggunakan AI terutama LLM untuk membuat karya tulis, esai, tugas praktikum, atau artikel ilmiah secara penuh tanpa proses telaah mandiri dan tanpa menyertakan deklarasi/atribusi yang transparan, lalu mengklaimnya sebagai hasil pemikiran orisinal.
# *   Manipulasi Informasi, pemanfaatan AI untuk menyebarkan konten palsu atau sistem penyeleksian berbasis AI yang mendiskriminasi kelompok tertentu akibat bias data latih.
# *   Pelanggaran Hak Cipta, pemanfaatan data, karya seni, atau publikasi ilmiah berhak cipta tanpa izin sebagai korpus data latih untuk melatih sistem AI.
#
# Referensi: Perpustakaan Universitas Brawijaya. (2025). Etika dan Potensi AI dalam Dunia Akademik. Diakses dari https://lib.ub.ac.id/featured/etika-dan-potensi-ai-dalam-dunia-akademik/
#
# <br>
#
# 2.   Contoh dampak energi dan lingkungan dan cara mengatasinya
#
# *   Konsumsi Listrik Tinggi, training model AI besar membutuhkan daya komputasi masif yang meningkatkan jejak karbon.
# *   Pemborosan Air, sistem pendingin server data center AI mengonsumsi jutaan liter air tawar.
# *   Limbah Elektroni, pergantian perangkat keras AI yang cepat memicu penumpukan sampah elektronik usang.
#
# Pendapat pribadi
# AI adalah Kemajuan teknologi tidak dapat dihindari. maka dari itu kita harus memanfaatkan kemajuan teknologi ini dengan bijak, contohnya menggunakan model AI yang sesuai dengan kebutuhan kita dan tidak membuang token untuk hal-hal yang ringan.
#
# Referensi: Perpustakaan Universitas Brawijaya. (2025). Pengenalan Artificial Intelligence dalam Dunia Akademik: Peluang dan Tantangan. Diakses dari https://lib.ub.ac.id/featured/pengenalan-artificial-intelligence-dalam-dunia-akademik-peluang-dan-tantangan/
